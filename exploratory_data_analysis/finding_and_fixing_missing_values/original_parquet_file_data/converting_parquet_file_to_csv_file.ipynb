# %%
import pandas as pd

# %% [markdown]
# ### Reading `.parquet` file

# %%
taxi_trips = pd.read_parquet(r"yellow_tripdata_2019-01.parquet")

# %%
# taxi_trips.head(10)

taxi_trips
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0               1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0  \
# 1               1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2               2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3               2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4               2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
# ...           ...                  ...                   ...              ...
# 7696612         2  2019-01-31 23:37:20   2019-02-01 00:10:43              NaN
# 7696613         2  2019-01-31 23:28:00   2019-01-31 23:50:50              NaN
# 7696614         2  2019-01-31 23:11:00   2019-01-31 23:46:00              NaN
# 7696615         2  2019-01-31 23:03:00   2019-01-31 23:14:00              NaN
# 7696616         2  2019-01-31 23:41:03   2019-02-01 00:19:16              NaN
#
# ...

# %% [markdown]
# ### Writing dataframe to `.csv` file

# %%
# taxi_trips.to_csv('yellow_tripdata_2019-01.csv', index=False)

# %% [markdown]
# ### Reading newly created `.csv` file

# %%
# df = pd.read_csv(r"yellow_tripdata_2019-01.csv")

# %%
# df

# %% [markdown]
# ###  Removing / filtering unnecessary columns

# %%
 df2 = taxi_trips[['tpep_pickup_datetime', 'passenger_count', 'trip_distance', 'PULocationID', 'payment_type', 'total_amount']]

df2

# type(df2)
# Out:
#         tpep_pickup_datetime  passenger_count  trip_distance  PULocationID
# 0        2019-01-01 00:46:40              1.0           1.50           151  \
# 1        2019-01-01 00:59:47              1.0           2.60           239
# 2        2018-12-21 13:48:30              3.0           0.00           236
# 3        2018-11-28 15:52:25              5.0           0.00           193
# 4        2018-11-28 15:56:57              5.0           0.00           193
# ...                      ...              ...            ...           ...
# 7696612  2019-01-31 23:37:20              NaN          10.24           142
# 7696613  2019-01-31 23:28:00              NaN          12.43            48
# 7696614  2019-01-31 23:11:00              NaN           9.14           159
# 7696615  2019-01-31 23:03:00              NaN           0.00           265
# 7696616  2019-01-31 23:41:03              NaN          12.30           237
#
#          payment_type  total_amount
# ...

# %%
df2.to_csv('yellow_tripdata_2019-01.csv', index=False)

# %%
df2
# Out:
#         tpep_pickup_datetime  passenger_count  trip_distance  PULocationID
# 0        2019-01-01 00:46:40              1.0           1.50           151  \
# 1        2019-01-01 00:59:47              1.0           2.60           239
# 2        2018-12-21 13:48:30              3.0           0.00           236
# 3        2018-11-28 15:52:25              5.0           0.00           193
# 4        2018-11-28 15:56:57              5.0           0.00           193
# ...                      ...              ...            ...           ...
# 7696612  2019-01-31 23:37:20              NaN          10.24           142
# 7696613  2019-01-31 23:28:00              NaN          12.43            48
# 7696614  2019-01-31 23:11:00              NaN           9.14           159
# 7696615  2019-01-31 23:03:00              NaN           0.00           265
# 7696616  2019-01-31 23:41:03              NaN          12.30           237
#
#          payment_type  total_amount
# ...
