# %% [markdown]
# #  two kinds of sorting available in Pandas.

# %% [markdown]
# # 1> By Label
# # 2> By Actual Value

# %% [markdown]
# # In the below unsorted_df  DataFrame, labels and the values are unsorted.

# %%
import pandas as pd
import numpy as np

unsorted_df=pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns=['col2','col1'])
unsorted_df
# Out:
#        col2      col1
# 1  0.552255  0.006513
# 4  0.732613 -1.854394
# 6  0.611994 -0.826420
# 2 -0.685084 -0.692002
# 3  0.065187 -0.833804
# 5 -0.051521  2.088999
# 9 -1.103645 -0.271828
# 8 -1.280807  0.114900
# 0  0.220593  0.692890
# 7  0.437666 -0.449634

# %% [markdown]
# # 1>  Sorting -->  By Label : Using the sort_index() method

# %%
import pandas as pd
import numpy as np

unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])

# %%
unsorted_df
# Out:
#        col2      col1
# 1 -0.453485  1.331491
# 4 -0.745759 -1.628092
# 6  0.359203 -0.418176
# 2  0.635140 -0.112600
# 3 -1.025399  0.344806
# 5 -0.009149  0.460818
# 9 -1.012806  0.486729
# 8  0.782806 -0.984143
# 0 -0.383088 -1.350573
# 7  1.459130  2.410006

# %%
sorted_df=unsorted_df.sort_index()
sorted_df
# Out:
#        col2      col1
# 0 -0.383088 -1.350573
# 1 -0.453485  1.331491
# 2  0.635140 -0.112600
# 3 -1.025399  0.344806
# 4 -0.745759 -1.628092
# 5 -0.009149  0.460818
# 6  0.359203 -0.418176
# 7  1.459130  2.410006
# 8  0.782806 -0.984143
# 9 -1.012806  0.486729

# %% [markdown]
# # Order of Sorting

# %% [markdown]
# # By passing the Boolean value to ascending parameter, the order of the sorting can be controlled.

# %%
import pandas as pd
import numpy as np

unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])

# %%
unsorted_df
# Out:
#        col2      col1
# 1  0.702847 -0.103968
# 4 -0.101335 -0.172337
# 6  1.101383 -0.571445
# 2  2.645648 -0.434823
# 3 -1.580718  0.019142
# 5  0.180559 -0.006623
# 9 -1.331187 -0.925012
# 8 -0.430837 -0.658355
# 0 -1.763308  0.051708
# 7 -1.195773 -0.285118

# %%
sorted_df = unsorted_df.sort_index(ascending=False)
sorted_df
# Out:
#        col2      col1
# 9 -1.331187 -0.925012
# 8 -0.430837 -0.658355
# 7 -1.195773 -0.285118
# 6  1.101383 -0.571445
# 5  0.180559 -0.006623
# 4 -0.101335 -0.172337
# 3 -1.580718  0.019142
# 2  2.645648 -0.434823
# 1  0.702847 -0.103968
# 0 -1.763308  0.051708

# %% [markdown]
# # Sort the Columns

# %%
import pandas as pd
import numpy as np
 
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])

# %%
unsorted_df
# Out:
#        col2      col1
# 1 -1.121281 -0.271585
# 4  0.268428 -0.623164
# 6  0.548069  1.105274
# 2 -0.094220  0.969705
# 3 -0.396214 -0.207971
# 5 -0.446814  1.916680
# 9  0.320205  0.027850
# 8  0.872292 -1.048363
# 0 -0.633195  0.160445
# 7 -1.679631 -1.914120

# %%
sorted_df=unsorted_df.sort_index(axis=1)        #  khas yo line of code le column ko index lai chai sorting gareko xa
sorted_df
# Out:
#        col1      col2
# 1 -0.271585 -1.121281
# 4 -0.623164  0.268428
# 6  1.105274  0.548069
# 2  0.969705 -0.094220
# 3 -0.207971 -0.396214
# 5  1.916680 -0.446814
# 9  0.027850  0.320205
# 8 -1.048363  0.872292
# 0  0.160445 -0.633195
# 7 -1.914120 -1.679631

# %% [markdown]
# # 2>  Sorting : By Value

# %% [markdown]
# # sort_values() is the method for sorting by values. It accepts a 'by' argument which will use the column name of the DataFrame with which the values are to be sorted.

# %%
import pandas as pd
import numpy as np

unsorted_df = pd.DataFrame({'col1':[2,1,1,1],'col2':[1,3,2,4]})

# %%
unsorted_df
# Out:
#    col1  col2
# 0     2     1
# 1     1     3
# 2     1     2
# 3     1     4

# %%
sorted_df = unsorted_df.sort_values(by=['col1','col2'])              # Note : both column ko value lai sorted garda pani completely value chai sorted vayera aaudaina
sorted_df
# Out:
#    col1  col2
# 2     1     2
# 1     1     3
# 3     1     4
# 0     2     1

# %% [markdown]
# # Sorting Algorithm

# %% [markdown]
# # sort_values() provides a provision to choose the algorithm from mergesort, heapsort and quicksort. Mergesort is the only stable algorithm.

# %%
import pandas as pd
import numpy as np

unsorted_df = pd.DataFrame({'col1':[2,1,1,1],'col2':[1,3,2,4]})

# %%
unsorted_df
# Out:
#    col1  col2
# 0     2     1
# 1     1     3
# 2     1     2
# 3     1     4

# %%
sorted_df = unsorted_df.sort_values(by='col1' ,kind='mergesort')
sorted_df
# Out:
#    col1  col2
# 1     1     3
# 2     1     2
# 3     1     4
# 0     2     1
