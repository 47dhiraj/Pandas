# %% [markdown]
# # Pip to be installed :

# %% [markdown]
# # 1>  pip install sqlalchemy

# %% [markdown]
# #  2>  pip install lxml

# %% [markdown]
# # 3>  pip install html5lib

# %% [markdown]
# # 4> pip install BeautifulSoup4

# %% [markdown]
# # 5>  pip install xlrd

# %% [markdown]
# # All Requirements for CSV (Comma Separated Values) File and MySQL

# %% [markdown]
# # 1> pip install sqlalchemy

# %% [markdown]
# # 2> pip install pymysql

# %% [markdown]
# # All Requirements for EXCEL ( .xlsx ) file

# %% [markdown]
# # 1> pip install sqlalchemy

# %% [markdown]
# # 2> pip install lxml

# %% [markdown]
# # 3> pip install xlrd

# %% [markdown]
# # 4> pip install openpyxl
